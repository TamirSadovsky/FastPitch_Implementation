# %%
# !git clone https://github.com/TamirSadovsky/FastPitch_Implementation.git
# Out:
# Cloning into 'FastPitch_Implementation'...
# remote: Enumerating objects: 166, done.
# remote: Counting objects: 100% (166/166), done.
# remote: Compressing objects: 100% (143/143), done.
# remote: Total 166 (delta 33), reused 150 (delta 20), pack-reused 0
# Receiving objects: 100% (166/166), 1.77 MiB | 1.32 MiB/s, done.
# Resolving deltas: 100% (33/33), done.

# %%
# %cd FastPitch_Implementation
# Out:
# /content/FastPitch_Implementation

# %%
# !mv ./FastPitch/* ./

# Remove the now empty FastPitch folder
# !rm -r ./FastPitch/

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Cloning https://github.com/NVIDIA/dllogger (to revision v1.0.0) to /tmp/pip-install-469w4256/dllogger_15c293d0b44d47a795341acd09ae0a7c
#   Running command git clone --filter=blob:none --quiet https://github.com/NVIDIA/dllogger /tmp/pip-install-469w4256/dllogger_15c293d0b44d47a795341acd09ae0a7c
#   Resolved https://github.com/NVIDIA/dllogger to commit 0540a43971f4a8a16693a9de9de73c1072020769
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.7/211.7 kB 3.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.1/46.1 kB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.7/195.7 kB 23.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 59.4 MB/s eta 0:00:00
# ...
#   Created wheel for dllogger: filename=DLLogger-1.0.0-py3-none-any.whl size=5654 sha256=bc98de7201ce7fef4075ab2ab6ca7962298da33e71c3226bf58eaa90f4aec74f
# ...

# %% [markdown]
# Because the downloading of the dataset can take long time.
# We shared with your gmail account the dataset folder.
# Please follow these steps:
# 1. Go to your Google Drive and locate the folder that has been shared with you named "LJSpeech-1.1".
# 2. Click on the "Add shortcut to Drive" option. This will add the folder to your Google Drive (Click Organize -> Add shortcut). **IMPORTANT!** use the MyDrive location (so the access to it will be by MyDrive/LJSpeech-1.1).
# 3. After it, run the next steps.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# These remove the changes we made in the training script to run in Slurm.

# %%
# Read the content of the file
with open("./scripts/noApex_train.sh", "r") as file:
    file_content = file.read()

# Prompt the user to input the new dataset path
new_dataset_path = '/content/drive/MyDrive/LJSpeech-1.1'

# Replace the DATASET_PATH value in the content
file_content = file_content.replace('${DATASET_PATH:=LJSpeech-1.1}', '${DATASET_PATH:="%s"}' % new_dataset_path)

# Write the modified content back to the file
with open("./scripts/noApex_train.sh", "w") as file:
    file.write(file_content)

# Read the content of the file
with open("./scripts/noApex_train.sh", "r") as file:
    file_content = file.read()

# Remove the specified line
line_to_remove = 'ARGS+=" --checkpoint-path /home/yandex/APDL2324a/group_3/DeepLearningExamples/PyTorch/SpeechSynthesis/FastPitch/output2/FastPitch_checkpoint_220.pt"'
file_content = file_content.replace(line_to_remove, '')

# Write the modified content back to the file
with open("./scripts/noApex_train.sh", "w") as file:
    file.write(file_content)

# %%
# Define the line to add at the end of the file
line_to_add = "python train_noapex.py $ARGS"

# Read the content of the file
with open("./scripts/noApex_train.sh", "r") as file:
    file_content = file.read()

# Append the line to the content
file_content += "\n" + line_to_add

# Write the modified content back to the file
with open("./scripts/noApex_train.sh", "w") as file:
    file.write(file_content)

# %%
# !chmod +x ./scripts/noApex_train.sh
# !bash ./scripts/noApex_train.sh
# Out:
# in new_train.sh
#
# WARNING: Global batch size changed from 256 to 64.
#
# AMP=false, 4x8x2 (global batch size 64)
#
# --cuda -o ./output4 --log-file ./output4/nvlog.json --dataset-path /content/drive/MyDrive/LJSpeech-1.1 --training-files filelists/ljs_audio_pitch_text_train_v3.txt --validation-files filelists/ljs_audio_pitch_text_val.txt -bs 8 --grad-accumulation 2 --optimizer lamb --epochs 1000 --epochs-per-checkpoint 20 --warmup-steps 1000 -lr 0.01 --weight-decay 1e-6 --grad-clip-thresh 1000.0 --dur-predictor-loss-scale 0.1 --pitch-predictor-loss-scale 0.1 --trainloader-repeats 100 --validation-freq 10 --kl-loss-start-epoch 0 --kl-loss-warmup-epochs 100 --text-cleaners english_cleaners_v2 --n-speakers 1 --p-arpabet 1.0 --energy-conditioning --load-pitch-from-disk --resume
# ...
